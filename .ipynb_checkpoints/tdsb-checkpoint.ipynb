# %%
import PyPDF2
import pandas

# %%
from tabula import read_pdf
from tabula import conver_into
df = read_pdf("~/Downloads/TDSB_School_list_Elem_Registration_Reports.pdf")

# %%
df
# Out:
#                                   Elementary Students Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN        NaN         NaN
# 1                                                 NaN  Enrolment         NaN
# 2                                                 NaN        NaN         NaN
# 3   LC4 LN23 - Marc Sprack Adam Beck Junior Public...        556         NaN
# 4   LC2 LN11 - Audley Salmon Africentric Alternati...         85         NaN
# ..                                                ...        ...         ...
# 82  LC3 LN13 - Kurt McIntosh Charles Gordon Senior...        373         NaN
# 83  LC2 LN08 - Elizabeth Addo Charles H Best Junio...        396         NaN
# 84  LC3 LN16 - Shirley Chan Charlottetown Junior P...        369         NaN
# 85  LC3 LN17 - Diana Panagiotopoulos Chartland Jun...        193         NaN
# 86   LC2 LN09 - Courtney Lewis Cherokee Public School        170         NaN
#
# ...
